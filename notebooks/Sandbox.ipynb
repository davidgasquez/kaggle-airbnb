# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from xgboost.sklearn import XGBClassifier

import sys
sys.path.append('..')
from utils.multiclassification import CustomOneVsOneClassifier

# %%
path = '../datasets/processed/'
train_users = pd.read_csv(path + 'train_users.csv')
train_users = train_users.head(15000)
train_users.fillna(-1, inplace=True)
test_users = pd.read_csv(path + 'test_users.csv')
test_users = test_users.head(15000)
test_users.fillna(-1, inplace=True)

# %%
y_train = train_users['country_destination']
train_users.drop('country_destination', axis=1, inplace=True)
train_users.drop('id', axis=1, inplace=True)

x_train = train_users.values

test_users.drop('id', axis=1, inplace=True)

x_test = test_users.values

label_encoder = LabelEncoder()
encoded_y_train = label_encoder.fit_transform(y_train)

# %%
xgb = XGBClassifier(
    max_depth=1,
    learning_rate=0.2,
    n_estimators=4,
    gamma=0,
    min_child_weight=1,
    max_delta_step=0,
    subsample=0.6,
    colsample_bytree=0.6,
    colsample_bylevel=1,
    reg_alpha=0,
    reg_lambda=1,
    scale_pos_weight=1,
    base_score=0.5,
    seed=42
)

# %%
clf = CustomOneVsOneClassifier(xgb, sampling='SMOTE')

# %%
clf.fit(x_train, encoded_y_train)
# Out:
# Determining classes statistics... 2 classes detected: {0: 48, 1: 171}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 123 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 48, 1: 115}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 67 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 48, 1: 242}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 194 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 48, 1: 599}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 551 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 48, 1: 213}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 165 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 48, 1: 237}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 189 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 48, 1: 6745}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 6697 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 48, 1: 81}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 33 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 48, 1: 26}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 22 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 48, 1: 5868}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 5820 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 48, 1: 655}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 607 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 171, 1: 115}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 56 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 171, 1: 242}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 71 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 171, 1: 599}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 428 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 171, 1: 213}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 42 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 171, 1: 237}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 66 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 171, 1: 6745}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 6574 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 171, 1: 81}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 90 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 171, 1: 26}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 145 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 171, 1: 5868}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 5697 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 171, 1: 655}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 484 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 115, 1: 242}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 127 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 115, 1: 599}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 483 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 115, 1: 213}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 98 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 115, 1: 237}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 122 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 115, 1: 6745}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 6630 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 115, 1: 81}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 34 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 115, 1: 26}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 89 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 115, 1: 5868}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 5753 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 115, 1: 655}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 540 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 242, 1: 599}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 357 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 242, 1: 213}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 29 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 242, 1: 237}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 5 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 242, 1: 6745}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 6503 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 242, 1: 81}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 161 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 242, 1: 26}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 216 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 242, 1: 5868}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 5626 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 242, 1: 655}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 413 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 599, 1: 213}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 386 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 599, 1: 237}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 362 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 599, 1: 6745}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 6146 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 599, 1: 81}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 518 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 599, 1: 26}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 573 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 599, 1: 5868}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 5269 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 599, 1: 655}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 56 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 213, 1: 237}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 24 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 213, 1: 6745}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 6532 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 213, 1: 81}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 132 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 213, 1: 26}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 187 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 213, 1: 5868}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 5655 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 213, 1: 655}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 442 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 237, 1: 6745}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 6508 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 237, 1: 81}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 156 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 237, 1: 26}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 211 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 237, 1: 5868}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 5631 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 237, 1: 655}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 418 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 6745, 1: 81}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 6664 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 6745, 1: 26}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 6719 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 6745, 1: 5868}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 877 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 6745, 1: 655}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 6090 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 81, 1: 26}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 55 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 81, 1: 5868}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 5787 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 81, 1: 655}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 574 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 26, 1: 5868}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 5842 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 26, 1: 655}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 629 new samples ...
# done!
# Determining classes statistics... 2 classes detected: {0: 5868, 1: 655}
# Finding the 5 nearest neighbours...done!
# Creating synthetic samples...Generated 5213 new samples ...
# done!
# CustomOneVsOneClassifier(estimator=XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.6,
#        gamma=0, learning_rate=0.2, max_delta_step=0, max_depth=1,
#        min_child_weight=1, missing=None, n_estimators=4, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=42, silent=True, subsample=0.6),
#              n_jobs=1, sampling='SMOTE')

# %%
preds = clf.predict_proba(x_train)
